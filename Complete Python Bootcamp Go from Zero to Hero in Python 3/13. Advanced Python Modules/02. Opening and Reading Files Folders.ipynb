# %%
pwd
# Out:
# 'C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules'

# %%
f = open('practice.txt', 'w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
# current working directory
os.getcwd()
# Out:
# 'C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules'

# %%
# list all the items in current working directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01. Collections-Module.ipynb',
#  '02. Opening and Reading Files Folders.ipynb',
#  '03. Datetime-Module.ipynb',
#  '04. Python Debugger (pdb).ipynb',
#  '05. Regular Expressions.ipynb',
#  '06. Timing your code - timeit.ipynb',
#  '07-Advanced-Modules-Exercise-Puzzle.ipynb',
#  '08-Advanced-Modules-Exercise-Solutions.ipynb',
#  'practice.txt',
#  'unzip_me_for_instructions.zip']

# %%
# list all the items at particular location
os.listdir('C:\\Users')
# Out:
# ['Administrator',
#  'All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'MUSR_MQADMIN',
#  'Public',
#  'u722912']

# %%
import shutil

# %%
shutil.move('practice.txt','C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules\\test' )
# Out:
# 'C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules\\test\\practice.txt'

# %%
os.listdir('C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules\\test')
# Out:
# ['practice.txt']

# %%
# To remove single file
os.unlink('C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules\\test\\practice.txt')

# %%
os.listdir('C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules\\test')
# Out:
# []

# %%
# To remove directory

# %%
os.rmdir('C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules\\test')

# %%
os.listdir('C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3\\13. Advanced Python Modules')
# Out:
# ['.ipynb_checkpoints',
#  '01. Collections-Module.ipynb',
#  '02. Opening and Reading Files Folders.ipynb',
#  '03. Datetime-Module.ipynb',
#  '04. Python Debugger (pdb).ipynb',
#  '05. Regular Expressions.ipynb',
#  '06. Timing your code - timeit.ipynb',
#  '07-Advanced-Modules-Exercise-Puzzle.ipynb',
#  '08-Advanced-Modules-Exercise-Solutions.ipynb',
#  'unzip_me_for_instructions.zip']

# %%
file_path = 'C:\\Users\\u722912\\Trial\\go-python-over\\Complete Python Bootcamp Go from Zero to Hero in Python 3'
for folder, sub_folder,files in os.walk(file_path):
    
    print(f'Currently looking at: {folder}')
    print('\n') 
    print('The sub folders are :')
    for sub_fold in sub_folder:
        print(f'Sub Folder : {sub_fold}')
    print('\n')
    print('The files are : ')
    for f in files:
        print(f'Sub Folder : {f}')
    print('\n')
# Out:
# Currently looking at: C:\Users\u722912\Trial\go-python-over\Complete Python Bootcamp Go from Zero to Hero in Python 3
#
#
# The sub folders are :
# Sub Folder : .ipynb_checkpoints
# Sub Folder : 01. Python Setup
# Sub Folder : 02. Python Object and Data Structure Basics
# Sub Folder : 03. Python Comparison Operators
# Sub Folder : 04. Python Statements
# Sub Folder : 05. Methods and Functions
# Sub Folder : 06. Milestone Project-1
# Sub Folder : 07. Object Oriented Programming
# Sub Folder : 08. Modules and Packages
# Sub Folder : 09. Errors and Exceptions Handling
# Sub Folder : 10. Milestone Project-2
# Sub Folder : 11. Python Decorators
# Sub Folder : 12. Python Generators
# Sub Folder : 13. Advanced Python Modules
#
#
# The files are :
#
#
# Currently looking at: C:\Users\u722912\Trial\go-python-over\Complete Python Bootcamp Go from Zero to Hero in Python 3\.ipynb_checkpoints
#
#
# The sub folders are :
#
#
# The files are :
# Sub Folder : FirstNotebook-checkpoint.ipynb
# ...
